# %%
from demo_utils.playground import auto_demo
from demo_utils.demo0 import Demo0

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# # Segment

# %%
Demo0().non_interactive(**auto_demo('logit', 'segment'))

# %% [markdown]
# # MNIST

# %%
d = Demo0()

# %%
d.non_interactive(**auto_demo('logit', 'mnist'))
# Out:
# # Una demo genérica
# -------Ha habido un error
# /home/hobber/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8157d9113c0f> in <module>
# ----> 1 d.non_interactive(**auto_demo('logit', 'mnist'))
#
# ~/git/TFG/code/notebooks/python/demo_utils/generic_demo.py in non_interactive(self, **argw)
#      61         display(md(self.desc))
#      62         train_scores, test_scores = self.run_demo(**argw)
# ---> 63         fig = self.get_generic_graph_from_scores(train_scores, test_scores)
#      64         # fig.suptitle(self.title)
#      65         display(md(self.run_specific))
#
# ...

# %%
e = d.ERRORS

# %%
er = e[0]

# %%
er.keys()
# Out:
# dict_keys(['clf', 'data_train', 'target_train', 'error', 'is_black', 'n_features'])

# %%
er['clf']
# Out:
# BaggingClassifier(base_estimator=Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=0.9, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)), ('sampler', RBFSampler(gamma=0.2, n_components=108, random_state=None)), ('model', LogisticRegression(C=1, class_weight=No...nalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))]),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=None, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)

# %%
er['error']
# Out:
# numpy.linalg.linalg.LinAlgError('SVD did not converge')

# %%
er['is_black']
# Out:
# False

# %%
er['n_features']
# Out:
# 108

# %%
clf = er['clf']

# %%
clf.fit(er['data_train'], er['target_train'])
# Out:
# BaggingClassifier(base_estimator=Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=0.9, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)), ('sampler', RBFSampler(gamma=0.2, n_components=108, random_state=None)), ('model', LogisticRegression(C=1, class_weight=No...nalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))]),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=None, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)

# %%
for i in range(100):
    print(i)
    clf.fit(er['data_train'], er['target_train'])
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-20-a1565b7f9a74> in <module>
#       1 for i in range(100):
#       2     print(i)
# ----> 3     clf.fit(er['data_train'], er['target_train'])
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/bagging.py in fit(self, X, y, sample_weight)
#     242         self : object
#     243         """
# --> 244         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     245
#     246     def _fit(self, X, y, max_samples=None, max_depth=None, sample_weight=None):
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     372                 total_n_estimators,
#     373                 verbose=self.verbose)
# --> 374             for i in range(n_jobs))
#     375
#     376         # Reduce
#
# ...

# %%
list_estims = clf.estimators_

# %%
list_estims
# Out:
# []
