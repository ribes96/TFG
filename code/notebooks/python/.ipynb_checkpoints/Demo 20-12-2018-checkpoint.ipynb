# %%
from demo_utils.playground import auto_demo
from demo_utils.playground import auto_demo_fragmented
from demo_utils.demo0 import Demo0

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
segment_mods = auto_demo_fragmented('logit', 'segment')
mnist_mods = auto_demo_fragmented('logit', 'mnist')

# %% [markdown]
# # Segment

# %%
for m in segment_mods:
    Demo0().non_interactive(**m)
# Out:
# # Una demo genérica
# - Dataset: **segment**
# - Size: **1000**
# # Una demo genérica
# - Dataset: **segment**
# - Size: **1000**
# # Una demo genérica
# - Dataset: **segment**
# - Size: **1000**

# %% [markdown]
# # mnist

# %%
for m in mnist_mods:
    Demo0().non_interactive(**m)
# Out:
# # Una demo genérica
# - Dataset: **mnist**
# - Size: **1000**
# # Una demo genérica
# - Dataset: **mnist**
# - Size: **1000**
# # Una demo genérica
# - Dataset: **mnist**
# - Size: **1000**
