# %% [markdown]
# Todo el proceso de experimentar con el dataset MNIST

# %%
# %load_ext jupyternotify

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from demo_utils.demo0 import Demo0
from demo_utils.demo3 import Demo3
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from demo_utils.general import get_data
import warnings
d0 = Demo0()
d3 = Demo3()
testing_dataset = 'mnist'
sampler_name = 'rbf'
dts_size = 1000
features_range = (30, 1000)
model_names = {'dt': 'dt',
               'logit': 'logit',
               'lsvc': 'linear_svc'}
best_gammas = {
    'dt': 0.00001,
    'logit': 0.001,
    'linear_svc': 0.001,
}
run_mode = False

# %%
warnings.filterwarnings('ignore')
# warnings.filterwarnings('once')
#warnings.filterwarnings(action='once')

# %% [markdown]
# # Con los modelos simples

# %% [markdown]
# Ver cómo se comportan los modelos simples con este dataset

# %% [markdown]
# Habría que encontrar los mejores hiper-parámetros para cada uno de ellos

# %% [markdown]
# Los híper-parámetros que tienen son:
#
# **Decision Tree**:
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - min_weight_fraction_leaf
# - max_leaf_nodes
# - min_impurity_decrease
#
# **Logit**:
# - C
#
# **Linear SVM**:
# - C

# %% [markdown]
# ### HíperParámetros con DecisionTree

# %%
# %%notify
# if run_mode:
#     tuned_parameters = [{
#         'max_depth': [10, 100, 1000, 10000, 100000, None],
#         'min_samples_split': [2, 3, 4, 5, 6, 7, 8, 9],
#         'min_samples_leaf': [1, 2, 3, 4],
#         'min_weight_fraction_leaf': [.0, .1, .3],
#         'max_leaf_nodes': [10, 50, 100, 1000, None],
#         'min_impurity_decrease': [.0, .2, .6],
#     }]
#     clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, cv=10)
#     data = get_data(testing_dataset, n_ins=dts_size)
#     data_train = data['data_train']
#     data_test = data['data_test']
#     target_train = data['target_train']
#     target_test = data['target_test']
#
#     clf.fit(data_train, target_train)
#     dt_best_params = clf.best_params_
#     print('DecisionTree best params.')
#     print(dt_best_params)

# %% [markdown]
# - **max_depth**: 1000
# - **max_leaf_nodes**: 100
# - **min_impurity_decrease**: 0.0
# - **min_samples_leaf**: 1
# - **min_samples_split**: 2
# - **min_weight_fraction_leaf**: 0.0

# %% [markdown]
# ### HíperParámetros con Logit

# %%
# %%notify
# if run_mode:
#     tuned_parameters = [{
#         'C': [0.001, .001, .01, .1, 1, 10, 100],
#     }]
#     clf = GridSearchCV(LogisticRegression(multi_class='multinomial', solver='lbfgs'),
#                        tuned_parameters, cv=10, iid=False)
#     data = get_data(testing_dataset, n_ins=dts_size)
#     data_train = data['data_train']
#     data_test = data['data_test']
#     target_train = data['target_train']
#     target_test = data['target_test']
#
#     clf.fit(data_train, target_train)
#     print('LogisticRegression best params.')
#     logit_best_params = clf.best_params_
#     print(logit_best_params)

# %% [markdown]
# - **C**: 0.01

# %% [markdown]
# (Tener en cuenta que da un convergence warning, que aquí se ignora)

# %% [markdown]
# ### HíperParámetros con LinearSVC

# %%
# %%notify
# if run_mode:
#     tuned_parameters = [{
#         'C': [.000001, .00001, .0001, .001, .01, .1, 1],
#     }]
#     clf = GridSearchCV(LinearSVC(), tuned_parameters, cv=10, iid=False)
#     data = get_data(testing_dataset, n_ins=dts_size)
#     data_train = data['data_train']
#     data_test = data['data_test']
#     target_train = data['target_train']
#     target_test = data['target_test']
#
#     clf.fit(data_train, target_train)
#     print('LinearSVC best params.')
#     linear_svc_best_params = clf.best_params_
#     print(linear_svc_best_params)

# %% [markdown]
# - **C**: 0.001 (oscila un poco)

# %%
if not run_mode:    
    # Para no tener que ejecutar el CV otra vez
    dt_best_params = {
        'max_depth': 1000,
        'max_leaf_nodes': 100,
        'min_impurity_decrease': 0.0,
        'min_samples_leaf': 1,
        'min_samples_split': 2,
        'min_weight_fraction_leaf': 0.0
    }
    logit_best_params = {'C': 0.01}
    linear_svc_best_params = {'C': 0.001}

# %%
d0_data = {
    'dts_name': testing_dataset,
    'dts_size': dts_size,
    'features_range': features_range,
    'rbfsampler_gamma': 0.2,
    'nystroem_gamma': 0.2,
    'hparams': {
        'dt': dt_best_params,
        'logit': logit_best_params,
        'linearsvc': linear_svc_best_params,
    },
    'models': [
        {'model_name': 'dt',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        },
        {'model_name': 'logit',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        },
        {'model_name': 'linear_svc',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        }
    ]
}

d3_data = {
    'dts_name': testing_dataset,
    'dts_size': dts_size,
    'model_data':
        {'model_name': 'dt',
         'sampler_name': sampler_name,
         'pca_bool': False,
         'pca_first': False,
         'n_estim': None,
         'box_type': 'none'
        },
    'hparams': {
        'dt': dt_best_params,
        'logit': logit_best_params,
        'linearsvc': linear_svc_best_params,
    },
    'features_range': features_range
}

# %%
# %%notify
# d0.non_interactive(**d0_data)
# Out:
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…

# %% [markdown]
# No obtienen muy buenos resultados. A lo mejor con PCA mejora...

# %% [markdown]
# ### Añadiendo PCA

# %% [markdown]
# d0_data = {
#     'dts_name': testing_dataset,
#     'dts_size': dts_size,
#     'features_range': (30, 100),
#     'rbfsampler_gamma': 0.2,
#     'nystroem_gamma': 0.2,
#     'hparams': {
#         'dt': dt_best_params,
#         'logit': logit_best_params,
#         'linearsvc': linear_svc_best_params,
#     },
#     'models': [
#         {'model_name': 'dt',
#          'sampler_name': 'identity',
#          'box_type': 'none',
#          'n_estim': None,
#          'pca': False,
#          'pca_first': False
#         },
#         {'model_name': 'dt',
#          'sampler_name': 'identity',
#          'box_type': 'none',
#          'n_estim': None,
#          'pca': True,
#          'pca_first': False
#         },
#         {'model_name': 'dt',
#          'sampler_name': 'identity',
#          'box_type': 'none',
#          'n_estim': None,
#          'pca': True,
#          'pca_first': True
#         }
#     ]
# }

# %%
# %%notify -m "Fin de bucle"
# #model_name = 'dt'
# for model_name in model_names.values():
#     d0_data['models'][0]['model_name'] = model_name
#     d0_data['models'][0]['pca'] = False
#
#     d0_data['models'][1]['model_name'] = model_name
#     d0_data['models'][1]['pca'] = True
#     d0_data['models'][1]['pca_first'] = False
#
#     d0_data['models'][2]['model_name'] = model_name
#     d0_data['models'][2]['pca'] = True
#     d0_data['models'][2]['pca_first'] = True
#
#
#     d0.non_interactive(**d0_data)
#     %notify
# Out:
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…

# %% [markdown]
# PCA no tiene ningún efecto positivo con este problema. No lo vamos a usar

# %% [markdown]
# Vamos a probar ahora de añadir el sampler RFF

# %% [markdown]
# Primero hay que ver qué valores de gamma son adecuados

# %% [markdown]
# ## Sampler con los modelos simples

# %% [markdown]
# ### DT

# %%
# %%notify -m "Fin de bucle"
# for model_name in model_names.values():
#     d3_data['model_data']['model_name'] = model_name
#     d3.non_interactive(**d3_data)
#     %notify
# Out:
# ### Diferencias entre los valores de gamma
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Diferencias entre los valores de gamma
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Diferencias entre los valores de gamma
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…

# %% [markdown]
# Destaca **gamma** = 0.00001
#
# Todavía es un resultado muy malo, pero ya es mejor que aleatorio

# %% [markdown]
# Los mejores valores de gamma son:
# - **DT**: 1e-5 = 0.00001
# - **Logit**: 0.001
# - **Linear SVC**: 0.001

# %% [markdown]
# A pesar de que los resultados han mejorado con el valor adecuado de gamma para RFF, ya se ve que no será posible igualar los resultados respecto a no usarlo

# %% [markdown]
# Vamos a probar estos valores de gamma usando PCA, solo por si acaso

# %%
d0_data = {
    'dts_name': testing_dataset,
    'dts_size': dts_size,
    'features_range': features_range,
    'rbfsampler_gamma': 0.2,
    'nystroem_gamma': 0.2,
    'hparams': {
        'dt': dt_best_params,
        'logit': logit_best_params,
        'linearsvc': linear_svc_best_params,
    },
    'models': [
        {'model_name': 'dt',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        },
        {'model_name': 'logit',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        },
        {'model_name': 'linear_svc',
         'sampler_name': 'identity',
         'box_type': 'none',
         'n_estim': None,
         'pca': False,
         'pca_first': False
        }
    ]
}

# %%
new_model = dict(d0_data['models'][0])
d0_data['models'].append(new_model)

# %%
# %%notify -m "Fin de bucle"
# for model_name in model_names.values():
#     d0_data['rbfsampler_gamma'] = best_gammas[model_name]
#
#     d0_data['models'][0]['model_name'] = model_name
#     d0_data['models'][0]['sampler_name'] = sampler_name
#     d0_data['models'][0]['pca'] = False
#
#     d0_data['models'][1]['model_name'] = model_name
#     d0_data['models'][1]['sampler_name'] = sampler_name
#     d0_data['models'][1]['pca'] = True
#     d0_data['models'][1]['pca_first'] = False
#
#     d0_data['models'][2]['model_name'] = model_name
#     d0_data['models'][2]['sampler_name'] = sampler_name
#     d0_data['models'][2]['pca'] = True
#     d0_data['models'][2]['pca_first'] = True
#
#     d0_data['models'][3]['model_name'] = model_name
#     d0_data['models'][3]['sampler_name'] = 'identity'
#     d0_data['models'][3]['pca'] = False
#
#
#     d0.non_interactive(**d0_data)
#     %notify
# Out:
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
# ### Demo genérica
# Accordion(children=(HBox(children=(VBox(children=(HTML(value='<strong>Dataset</strong>: mnist'), HTML(value='<…
